# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../input/snapshot-round-1/snapshot_round_1.csv')
df.head()
# Out:
#          date                 campaign_name mktng_pgm_nbr  sendout  delivered  \
# 0  2021-12-31   Newsletter_prenatal_WithApp            US   152694     151834
# 1  2021-12-31   Newsletter_postnatal_NohApp            US    61709      61371
# 2  2021-12-31  Hello_Email_postnatall_NoApp            US        0          0
# 3  2021-12-31    Newsletter_postnatal_NoApp            US   103974     103210
# 4  2021-12-31    Hello_Email_prenatal_NoApp            US        0          0
#
#    people  unique_delivered  openers  clickers  clicked_or_opened  all_opens  \
# 0  153433            151834    38522      2726              38601      45520
# 1   61753             61371    13775      1242              13854      16808
# 2       4                 0        4         0                  4          4
# 3  104423            103210    20948      1323              21108      24391
# 4      20                 0       20         1                 20         26
#
#    all_clicks
# 0        3554
# ...
